# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Abdullah Syed**<br>                                                                                               Undergraduate Student

# %% [markdown]
# *One of the reasons I am interested in data science because I am curious about how decisions can be drawn from data to enhance products, services and efficiencies of different processes.*

# %% [markdown]
# ###The following code performs a basic arithmetic operation

# %%
1+2
# Out:
# 3

# %% [markdown]
# ![1_YPsZO50dIiEKpW9RqzqsTw.jpeg](attachment:979f17b0-a7aa-40de-be30-e625d841c8b4.jpeg)
# <br>
# - First bullet<br>
# - Second bullet<br>
# 1. numbered list<br>
# 2. numbered list<br>
# >This is a blocked quote

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>
